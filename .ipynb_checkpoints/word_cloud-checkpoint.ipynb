# %%
import pandas as pd

# %%
with open('./preprocessing/2024-06-18_20-00-17.txt') as file:
    isi=file.readlines()
isi
# Out:
# ["['array', 'korsel', 'lepas', 'tembakan', 'peringatan', 'gegara', 'tentara', 'korut', 'lintasi', 'perbatasan', 'netanyahu', 'bubarkan', 'kabinet', 'perang', 'nasib', 'gencatan', 'senjata', 'gaza', 'pks', 'tawaran', 'kim', 'cawagub', 'pilkada', 'dki', 'jakarta', 'viral', 'kucing', 'liar', 'gbk', 'dimasukkan', 'plastik', 'pengelola', 'buka', 'suara', 'polisi', 'ultimatum', 'jambret', 'viral', 'cfd', 'serahkan', 'lacak', 'wajahpelat', 'nomor', 'kecelakaan', 'mobil', 'boks', 'melintang', 'tol', 'jagorawi', 'lalin', 'macet', 'arah', 'update', 'terbaru', 'penggelapan', 'mobil', 'bos', 'rental', 'tewas', 'pati', 'pks', 'tawaran', 'cawagub', 'dki', 'partai', 'kim', 'gerindra', 'arus', 'libur', 'idul', 'adha', 'titik', 'tol', 'arah', 'jakarta', 'macet', 'warga', 'sumedang', 'rumahnya', 'kiriman', 'sampah', 'maaf', 'pembuang', 'sampah', 'sembarangan', 'sumedang', 'terungkap', 'paket', 'belanja', 'online', 'polisi', 'tangsel', 'memar', 'duel', 'lawan', 'sapi', 'ngamuk', 'diseruduk', 'polisi', 'panggil', 'korban', 'dugaan', 'pelecehan', 'rektor', 'up', 'nonaktif', 'besok', 'muncul', 'desakan', 'muktamar', 'dipercepat', 'ppp', 'tegaskan', 'pria', 'tusuk', 'orang', 'malam', 'takbiran', 'bogor', 'pesta', 'miras', 'pengunjung', 'monas', 'ramai', 'idul', 'adha', 'omzet', 'pedagang', 'melonjak', 'heboh', 'mobil', 'dikejar', 'menuruni', 'parkiran', 'mal', 'bandung', 'faktanya', 'cak', 'imin', 'sorot', 'tenda', 'sempit', 'mina', 'ruang', 'gerak', 'jemaah', 'meter', 'viral', 'sejoli', 'dikejar', 'diduga', 'mesum', 'mobil', 'parkiran', 'mal', 'bandung', 'jne', 'bagikan', 'daging', 'kurbanhadirkan', 'promo', 'spesial', 'momen', 'idul', 'adha', 'viral', 'pria', 'depok', 'curi', 'motor', 'trail', 'tinggalkan', 'gorengan', 'tkp', 'nama', 'negatif', 'sukolilo', 'google', 'maps', 'diganti', 'berubah', 'foto', 'putinbendera', 'rusia', 'hiasi', 'jalanan', 'pyongyang', 'jelang', 'kunjung', 'langka', 'kpk', 'panggil', 'ulang', 'kusnadi', 'staf', 'hasto', 'besok', 'otk', 'bawa', 'kabur', 'motor', 'milik', 'remaja', 'depok', 'modus', 'tuduh', 'pelecehan', 'domba', 'awassi', 'seharga', 'rp', 'juta', 'pandeglang', 'dicuri', 'kandang', 'digergaji', 'warga', 'harap', 'hewan', 'kurban', 'langsung', 'istiqlal', 'antrean', 'waka', 'mpr', 'ingatkan', 'pengurangan', 'angka', 'prevalensi', 'stunting', 'butuh', 'keseriusan', 'putin', 'kunjungi', 'korut', 'penerbangannya', 'tekateki', 'waka', 'mpr', 'yandri', 'susanto', 'klaim', 'pelaksanaan', 'haji', 'bupati', 'sergai', 'masuk', 'bursa', 'wakil', 'bobby', 'pilgubsu', 'main', 'bola', 'bareng', 'siswa', 'smp', 'difabel', 'ditendang', 'kepalanya', 'disdik', 'penganiayaan', 'putin', 'puji', 'korut', 'jelang', 'kunjungan', 'pertamanya', 'bocoran', 'isi', 'pertemuan', 'kakak', 'cak', 'imin', 'calon', 'rival', 'khofifah', 'pria', 'tusuk', 'orang', 'malam', 'takbiran', 'gunungsindur', 'bogor', 'tewas', 'sindiran', 'keras', 'loyalis', 'suharso', 'majelis', 'ppp', 'desak', 'muktamar', 'sapi', 'kurban', 'tangsel', 'ngamuk', 'rusak', 'motor', 'duel', 'lawan', 'polisi', 'parlemen', 'thailand', 'setuju', 'ubah', 'uu', 'perkawinan', 'legalkan', 'nikah', 'sejenis', 'jemaah', 'haji', 'keluhkan', 'toilet', 'memadai', 'terpaksa', 'pipis', 'samping', 'tenda', 'viral', 'warga', 'sumedang', 'balikin', 'sampah', 'dibuang', 'sembarangan', 'pemilik', 'rumah', 'penulis', 'india', 'dijerat', 'uu', 'antiterorisme', 'gegara', 'pidatonya', 'majelis', 'ppp', 'surati', 'mardiono', 'dkk', 'desak', 'muktamar', 'digelar', 'gagal', 'dpr', 'detikdetik', 'pelajar', 'dijambret', 'cfd', 'lari', 'bareng', 'ortu', 'cerita', 'ashari', 'terbantu', 'lunasi', 'tunggakan', 'jkn', 'program', 'rehab', 'cerita', 'warga', 'jembrana', 'sapi', 'kurban', 'jokowi', 'bangkit', 'disembelih', 'pemprov', 'dki', 'jakarta', 'resmikan', 'kebijakan', 'insentif', 'fiskal', 'pbbp', 'polisi', 'korban', 'jambret', 'viral', 'cfd', 'pelajar', 'ponsel', 'raib', 'cek', 'tenda', 'jemaah', 'haji', 'ri', 'mina', 'cak', 'imin', 'keluhan', 'wckasur', 'arus', 'libur', 'idul', 'adha', 'ribu', 'pe ...

# %%
# Import the wordcloud library
from wordcloud import WordCloud
# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
# Generate a word cloud
wordcloud.generate(str(isi))
# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
# Save the image in the img folder:
wordcloud.to_file("img/2024-06-18_20-00-17.png")
